# %%
import pandas as pd

# %%
df = pd.read_csv("complaints.csv")
# Out:
# /media/kavya/DATA/Ubuntu/home/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df[(df['Product']="Mortgage")&(df['Issue']="Loan modification,collection,foreclosure")]
# Out:
#         Date received                                            Product  \
# 0          2019-05-03                                       Student loan
# 1          2021-12-31  Credit reporting, credit repair services, or o...
# 2          2019-05-24  Credit reporting, credit repair services, or o...
# 3          2022-03-20                                    Debt collection
# 4          2022-03-16  Credit reporting, credit repair services, or o...
# ...               ...                                                ...
# 2558158    2017-02-09                                    Debt collection
# 2558159    2015-04-29                                           Mortgage
# 2558160    2017-03-31                                   Credit reporting
# 2558161    2017-01-16                                   Credit reporting
# 2558162    2018-03-07                                           Mortgage
#
#                          Sub-product  \
# 0               Private student loan
# ...

# %%
df1 = df[(df['Product']=="Mortgage")&(df['Issue']=="Loan modification,collection,foreclosure")]

# %%
grouped = df1.groupby('Company').size().sort_values(ascending=False)

# %%
grouped[:10]
# Out:
# Company
# BANK OF AMERICA, NATIONAL ASSOCIATION    25075
# WELLS FARGO & COMPANY                    17355
# Ocwen Financial Corporation              11075
# JPMORGAN CHASE & CO.                      9743
# NATIONSTAR MORTGAGE                       7351
# CITIBANK, N.A.                            4706
# Ditech Financial LLC                      3787
# SELECT PORTFOLIO SERVICING, INC.          3499
# U.S. BANCORP                              2297
# HSBC NORTH AMERICA HOLDINGS INC.          2067
# dtype: int64
